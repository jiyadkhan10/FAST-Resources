# %%
import librosa
import soundfile as sf
import numpy as np

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\umair\anaconda3\lib\site-packages (from librosa) (0.24.1)
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
# Requirement already satisfied: numba>=0.43.0 in c:\users\umair\anaconda3\lib\site-packages (from librosa) (0.53.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\umair\anaconda3\lib\site-packages (from librosa) (1.6.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\umair\anaconda3\lib\site-packages (from librosa) (20.9)
# Requirement already satisfied: joblib>=0.14 in c:\users\umair\anaconda3\lib\site-packages (from librosa) (1.0.1)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\umair\anaconda3\lib\site-packages (from librosa) (5.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\umair\anaconda3\lib\site-packages (from librosa) (1.20.1)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
# Collecting pooch>=1.0
#   Downloading pooch-1.5.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\umair\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\umair\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\umair\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: requests in c:\users\umair\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: appdirs in c:\users\umair\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.3 in c:\users\umair\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\umair\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\umair\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\umair\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\umair\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\umair\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\umair\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\umair\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Building wheels for collected packages: audioread, resampy
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23141 sha256=bd9c82733b5938a2816231926322eb9eb9a5cf0791b0e1ecf6d44f538941a599
#   Stored in directory: c:\users\umair\appdata\local\pip\cache\wheels\49\5a\e4\df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320718 sha256=7c4e5f846fdebcc4b7d79516d308baefd6a42d4a7fd13f4fba1699d8da6073fb
#   Stored in directory: c:\users\umair\appdata\local\pip\cache\wheels\6f\d1\5d\f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
# Successfully built audioread resampy
# Installing collected packages: soundfile, resampy, pooch, audioread, librosa
# Successfully installed audioread-2.1.9 librosa-0.8.1 pooch-1.5.2 resampy-0.2.2 soundfile-0.10.3.post1

# %%
import librosa
audio_path = 'SM7_F20_H092.wav'
x , sr = librosa.load(audio_path)

# %%
X, sample_rate = sf.read('SM7_F20_H092.wav', dtype='float32')

# %%
hop_length = 512
chromagram = librosa.feature.chroma_stft(X, sr=sample_rate, hop_length=hop_length)
chromagram
# Out:
# array([[0.44002464, 0.11357998, 0.01483923, ..., 0.91989076, 0.5906363 ,
#         1.        ],
#        [0.25983304, 0.06371528, 0.01438615, ..., 1.        , 0.6225511 ,
#         0.6233836 ],
#        [0.21232116, 0.05495903, 0.02170697, ..., 0.81708354, 0.70860237,
#         0.4627927 ],
#        ...,
#        [0.93724954, 0.7129867 , 0.29764342, ..., 0.4019988 , 0.5170696 ,
#         0.81601804],
#        [0.75270027, 0.3537189 , 0.10878757, ..., 0.70882183, 0.66847485,
#         0.72707033],
#        [0.70630515, 0.17377524, 0.03229759, ..., 0.69750094, 0.5219423 ,
#         0.6497592 ]], dtype=float32)

# %%
plt.figure(figsize=(15, 5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=hop_length, cmap='coolwarm')

# %%
# Applying Short Term Fourier Transform
stft = np.abs(librosa.stft(X))
print (stft)

# %%
plt.figure(figsize=(20,8))
librosa.display.specshow(stft, sr=sample_rate, x_axis='time')

# %%
MFCC_Features = librosa.feature.mfcc(y=X, sr=sample_rate)
print (MFCC_Features)
# Out:
# [[-305.13223   -320.9903    -370.2086    ... -397.52228   -406.9715
#   -415.62204  ]
#  [ 181.57666    180.05518    168.76599   ...  112.85441    106.045074
#    106.03246  ]
#  [ -44.306107   -35.512672   -19.056862  ...  -27.426218   -28.697235
#    -19.927837 ]
#  ...
#  [ -22.216873   -25.36589    -18.10059   ...    7.1756535    7.915558
#     11.176521 ]
#  [ -10.833696    -7.497836    -3.51153   ...   -4.093008    -3.0668116
#     -0.51997  ]
#  [  10.969364    12.3971405    8.488083  ...  -11.111668   -10.04916
#     -7.79705  ]]

# %%
plt.figure(figsize=(20,8))
librosa.display.specshow(MFCC_Features, sr=sample_rate, x_axis='time')

# %%
X, sample_rate = sf.read('SM7_F20_H092.wav', dtype='float32')
import IPython.display as ipd
ipd.Audio(X,rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#display waveform
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(X, sr=sample_rate)
